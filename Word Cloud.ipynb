# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = "Python is easy. Python is powerful. Python is fun."

# Create a word cloud
wordcloud = WordCloud(width=400, height=200, background_color='black').generate(text)

# Show the word cloud
plt.figure(figsize=(10,5))
plt.imshow(wordcloud)
plt.axis("off")  # Hide axes
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
Text1 = "Hello my Name is Shrirang and i am 21 year old"
wordcloud = WordCloud(height=2000,width=2000,background_color='white').generate(Text1)
plt.imshow(wordcloud)
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.imshow(wordcloud)

# %%
import numpy as np
Text1 = np.array(Text1)

# %%
Text1
# Out:
# array('Hello my Name is Shrirang and i am 21 year old', dtype='<U46')

# %% [markdown]
# ### Work on Dataset

# %%
# Import Libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Import text data 
df = pd.read_csv(r"C:\Users\Shree\OneDrive\Desktop\FSDS_omkar sir\Datafiles\bank.csv",sep=';')
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df['job'].value_counts()
# Out:
# job
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# student           84
# unknown           38
# Name: count, dtype: int64

# %%
df['job'].iloc[0].split()[0]
# Out:
# 'unemployed'

# %%
for j in df.job:
    print(j.split()[0])
# Out:
# unemployed
# services
# management
# management
# blue-collar
# management
# self-employed
# technician
# entrepreneur
# services
# services
# admin.
# technician
# student
# blue-collar
# management
# technician
# admin.
# blue-collar
# services
# management
# management
# services
# entrepreneur
# housemaid
# management
# blue-collar
# retired
# self-employed
# admin.
# retired
# technician
# management
# management
# technician
# admin.
# retired
# blue-collar
# management
# services
# management
# management
# blue-collar
# technician
# technician
# management
# blue-collar
# blue-collar
# entrepreneur
# admin.
# blue-collar
# technician
# technician
# technician
# blue-collar
# admin.
# management
# self-employed
# retired
# technician
# blue-collar
# retired
# management
# services
# admin.
# blue-collar
# services
# technician
# management
# technician
# management
# entrepreneur
# management
# services
# retired
# management
# blue-collar
# technician
# blue-collar
# ...

# %%
text = ' '.join(j.split()[0] for j in df.job)
wordcloud = WordCloud(background_color='white').generate(text)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
